# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import fastai as meta_fai
import fastai.basics as fai
import fastai.vision as fv
from pathlib import Path
import pandas as pd
import random
import numpy as np
from collections import defaultdict
import gc
import torch
import torchvision.models
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import math
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

import PIL
from tqdm import tqdm_notebook as tqdm
from tqdm import trange

# %% [markdown]
# # Bug Spray ୧[ ˵ ͡ᵔ ͜ʟ ͡ᵔ ˵ ]୨

# %%
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
#!head train_photo_to_biz_ids.csv
#!ls train_photos | head
#!head train.csv

# %%
biz_label = pd.read_csv("train.csv").fillna('')
photo_biz = pd.read_csv("train_photo_to_biz_ids.csv")

# %%
#biz_label.head()
#photo_biz.head()

# %%
bizs, labels = biz_label['business_id'], biz_label['labels']
biz2label = {biz:label for biz,label in zip(bizs, labels)}

# %%
#biz2label

# %%
bizzes = list(biz2label.keys())

nvalid = 200

random.seed(13) # jajaja ... 13
random.shuffle(bizzes)
valid_biz, train_biz  = bizzes[:nvalid], bizzes[nvalid:]

# %%
torch.save(valid_biz, "valid_biz.list")
torch.save(train_biz, "train_biz.list")

# %%
photo2biz = {photo:biz for photo,biz in zip(photo_biz['photo_id'], photo_biz['business_id'])}

# %%
biz2photos = defaultdict(lambda : [])
for img,biz in photo2biz.items():
    biz2photos[biz].append(img)

# %%
photo_label = photo_biz.copy()
photo_label.business_id = photo_label.business_id.apply(lambda x: biz2label[x])
photo_label = photo_label.rename({"business_id":"labels"},axis=1);

# %%
#photo_label.head()
#photo_label.head()

# %%
def str2list(label):
    if label != label: return [] # if lbl == NaN
    return [int(x) for x in label.split()]

categories = ["good_for_lunch", "good_for_dinner", "takes_reservations", "outdoor_seating", "restaurant_is_expensive", "has_alcohol", "has_table_service", "ambience_is_classy", "good_for_kids"]

# %%
valid_dict = [0]*4001
for biz in valid_biz:
    valid_dict[biz] = 1
    
def is_valid(filename):
    pf = Path(filename)
    f = int(pf.stem)
    return valid_dict[photo2biz[f]]

# %%
def load_data(img_size, batch_size, amount=1):
    tfms = fv.get_transforms()
    return (fv.ImageItemList.from_df(photo_label,".",folder="train_photos", suffix='.jpg')
              .filter_by_rand(amount, seed=13)
              .split_by_valid_func(is_valid)
              .label_from_df(label_delim=' ') #dataframe
              .transform(tfms, size=img_size)
              .databunch(bs=batch_size))

# %%
data = load_data(224,64, amount=0.1)

# %%
data.show_batch(rows=3)

# %%
class F1_Score:
    def __init__(self,thresh:float):
        self.thresh = thresh
        
    def __call__(self,inp,targ):
        return meta_fai.metrics.fbeta(inp, targ, thresh=self.thresh, beta=1.)
    
    def __repr__(self):
        return f"F1({self.thresh})"
    
    @property
    def __name__(self):
        return self.__repr__()

# %%
metrics = [F1_Score(t) for t in [0.3, 0.35, 0.4, 0.43, 0.45, 0.60, 0.75]]

# %% [markdown]
# # Stop Here

# %%
learner = fv.create_cnn(data, fv.models.resnet101, metrics=metrics, wd=0.1)

# %%
learner.fit_one_cycle(5)

# %%
data = load_data(224,32)

# %%
learner.data = data

# %%
learner.fit_one_cycle(1)

# %%
learner.lr_find(); learner.recorder.plot()

# %%
learner.save("besto_parameters")

# %%
learner.fit_one_cycle(3,2e-1)

# %%
learner.save("big_cnn_101")

# %%
learner.unfreeze()

# %%
learner.lr_find(); learner.recorder.plot()

# %%
learner.fit_one_cycle(1,1e-3)

# %%
learner.lr_find(); learner.recorder.plot()

# %%
learner.fit_one_cycle(1,1e-2)

# %%
learner.save("simple_unfroze_cnn_101")

# %% [markdown]
# # Data Prep

# %%
learner = fv.create_cnn(data, fv.models.resnet101, metrics=metrics, wd=0.1)
learner.load("besto_parameters");

# %%
class SimpleTensorDataset(Dataset):
    def __init__(self, features, labels):
        super().__init__()
        assert len(features) == len(labels)
        self.features = [torch.tensor(f).float().cpu() for f in features]
        self.labels = [torch.tensor(l).float().cpu() for l in labels]
        
    def __len__(self):
        return len(self.features)

    def __getitem__(self, i):
        return self.features[i], self.labels[i]

# %%
class forward_net(nn.Module):
    def __init__(self, num_classes=9):
        super(forward_net, self).__init__()
        self.fc1 = nn.Linear(82, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, 128)
        self.fc5 = nn.Linear(128, 48)
        self.fc6 = nn.Linear(48, num_classes)
        self.relu = nn.LeakyReLU()
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.relu(out)
        out = self.fc4(out)
        out = self.relu(out)
        out = self.fc5(out)
        out = self.relu(out)
        out = self.fc6(out)
        return out

model = forward_net()

# %%
def stat_function(values,f):
    n = len(values)
    return torch.tensor([f(torch.tensor([values[i][x] for i in range(n)]),n) for x in range(9)])

def get_stats(values):
    n = len(values)
    all_Amean = stat_function(values,lambda col,n: sum(col)/n)
    all_Gmean = stat_function(values,lambda col,n: torch.prod(col)**(1/n))
    all_Hmean = stat_function(values,lambda col,n: 1/sum(torch.div(1,col)))
    all_Cmean = stat_function(values,lambda col,n: (sum(col**2)/n)**0.5)
    all_Gmean_mod = stat_function(values, lambda col,n: 1-torch.prod(1-col)**(1/n))
    all_max = stat_function(values,lambda col,n: max(col))
    all_min = stat_function(values,lambda col,n: min(col))
    all_range = stat_function(values,lambda col,n: max(col)-min(col))
    var = lambda col,n,x: sum((col-all_Amean[x])**2)/n
    all_var = torch.tensor([var(torch.tensor([values[i][x] for i in range(n)]),n,x) for x in range(9)])
    return torch.cat((all_Amean,all_Gmean,all_Hmean,all_Cmean,all_Gmean_mod,all_max,all_min,all_range,all_var,torch.FloatTensor([n])))

# %% [markdown]
# # Takes forever ［(－－)］zzz

# %% [markdown]
# *insert elevator music below*

# %%
import IPython
#!pip install youtube-dl
#!youtube-dl --extract-audio -o music.m4a https://www.youtube.com/watch?v=hJlq3g7HzrM 
IPython.display.Audio("music.m4a")

# %%
#!mkdir stored

train_stats = []
train_labels = []
for biz in train_biz:
    values = []
    r = len(biz2photos[biz])
    for photo_num in biz2photos[biz]:
        photo = fv.open_image("train_photos/"+str(photo_num)+".jpg")
        values.append(learner.predict(photo))
    pred = torch.tensor([list(v[2]) for v in values])
    
    train_stats.append(get_stats(pred))
    train_labels.append(values[0][1])

train_data = SimpleTensorDataset(train_stats,train_labels)
torch.save(train_data, "trainData_full")

# %%
valid_stats = []
valid_labels = []
for biz in valid_biz:
    values = []
    r = len(biz2photos[biz])
    for photo_num in biz2photos[biz]:
        photo = fv.open_image("train_photos/"+str(photo_num)+".jpg")
        values.append(learner.predict(photo))
    pred = torch.tensor([list(v[2]) for v in values])
    
    valid_stats.append(get_stats(pred))
    valid_labels.append(values[0][1])

valid_data = SimpleTensorDataset(valid_stats,valid_labels)
torch.save(valid_data, "validData_full")

# %% [markdown]
# # Training

# %%
#torch.save(train_data, "trainData")
#torch.save(valid_data, "validData")

# %%
train_data = torch.load("trainData_full")
valid_data = torch.load("validData_full")

# %%
print(len(train_data))
print(len(valid_data))
# Out:
# 1800
# 200

# %%
bunch = meta_fai.basic_train.DataBunch.create(train_ds=train_data, valid_ds=valid_data, bs=1)

# %%
learn = meta_fai.basic_train.Learner(bunch, model, wd=0.1, loss_func=F.binary_cross_entropy_with_logits, metrics=metrics)

# %%
learn.lr_find(); learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 00:44 <p><table style='width:600px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>F1(0.3)</th>
#     <th>F1(0.35)</th>
#     <th>F1(0.4)</th>
#     <th>F1(0.43)</th>
#     <th>F1(0.45)</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.553506</th>
#     <th>0.504255</th>
#     <th>0.706057</th>
#     <th>0.705645</th>
#     <th>0.688247</th>
#     <th>0.693034</th>
#     <th>0.694996</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.574379</th>
#     <th>0.520430</th>
#     <th>0.696789</th>
#     <th>0.690114</th>
#     <th>0.685770</th>
#     <th>0.679868</th>
#     <th>0.679639</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.522650</th>
#     <th>0.484352</th>
#     <th>0.698646</th>
#     <th>0.709633</th>
#     <th>0.715642</th>
#     <th>0.713196</th>
#     <th>0.683465</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.481449</th>
#     <th>0.439222</th>
#     <th>0.724139</th>
#     <th>0.735240</th>
#     <th>0.742229</th>
#     <th>0.740802</th>
#     <th>0.734608</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.443986</th>
#     <th>0.423812</th>
#     <th>0.741062</th>
#     <th>0.752933</th>
#     <th>0.755848</th>
#     <th>0.757822</th>
#     <th>0.752538</th>
#   </tr>
# </table>

# %%
bunch = meta_fai.basic_train.DataBunch.create(train_ds=train_data, valid_ds=valid_data, bs=1)

# %%
learn.data = bunch

# %%
learn.lr_find(); learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10,1e-3)
# Out:
# Total time: 01:30 <p><table style='width:750px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>F1(0.3)</th>
#     <th>F1(0.35)</th>
#     <th>F1(0.4)</th>
#     <th>F1(0.43)</th>
#     <th>F1(0.45)</th>
#     <th>F1(0.6)</th>
#     <th>F1(0.75)</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.417888</th>
#     <th>0.423973</th>
#     <th>0.745277</th>
#     <th>0.748735</th>
#     <th>0.748191</th>
#     <th>0.747671</th>
#     <th>0.752158</th>
#     <th>0.697982</th>
#     <th>0.639536</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.488781</th>
#     <th>0.460647</th>
#     <th>0.709427</th>
#     <th>0.704793</th>
#     <th>0.715653</th>
#     <th>0.723279</th>
#     <th>0.725085</th>
#     <th>0.678041</th>
#     <th>0.513793</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.450367</th>
#     <th>0.437396</th>
#     <th>0.738090</th>
#     <th>0.739107</th>
#     <th>0.731389</th>
#     <th>0.727528</th>
#     <th>0.696627</th>
#     <th>0.678220</th>
#     <th>0.610156</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.440985</th>
#     <th>0.508757</th>
#     <th>0.735804</th>
#     <th>0.735834</th>
#     <th>0.738573</th>
#     <th>0.729733</th>
#     <th>0.722331</th>
#     <th>0.610350</th>
#     <th>0.530863</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.471696</th>
#     <th>0.461186</th>
#     <th>0.725739</th>
#     <th>0.738115</th>
#     <th>0.740141</th>
#     <th>0.746280</th>
#     <th>0.738961</th>
#     <th>0.650775</th>
#     <th>0.560791</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.496518</th>
#     <th>0.450948</th>
#     <th>0.723401</th>
#     <th>0.733616</th>
#     <th>0.739041</th>
#     <th>0.742964</th>
#     <th>0.737352</th>
#     <th>0.655827</th>
#     <th>0.552062</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.508639</th>
#     <th>0.441006</th>
#     <th>0.724099</th>
#     <th>0.738663</th>
#     <th>0.750856</th>
#     <th>0.748724</th>
#     <th>0.749267</th>
#     <th>0.667320</th>
#     <th>0.590516</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.429841</th>
#     <th>0.418714</th>
#     <th>0.761129</th>
#     <th>0.760867</th>
#     <th>0.758570</th>
#     <th>0.756222</th>
#     <th>0.755364</th>
#     <th>0.691543</th>
#     <th>0.604323</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.453229</th>
#     <th>0.412117</th>
#     <th>0.753814</th>
#     <th>0.759421</th>
#     <th>0.766383</th>
#     <th>0.762507</th>
#     <th>0.758333</th>
#     <th>0.694799</th>
#     <th>0.636556</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.468614</th>
#     <th>0.411653</th>
#     <th>0.758257</th>
#     <th>0.764121</th>
#     <th>0.766421</th>
#     <th>0.768078</th>
#     <th>0.764510</th>
#     <th>0.691225</th>
#     <th>0.624328</th>
#   </tr>
# </table>

# %%
learn.save("Final_FC")

# %%
learn.lr_find(); learn.recorder.plot()

# %%
learn.fit_one_cycle(100,2e-5)

# %%
len(train_biz)

# %%
len(valid_biz)

# %%
learn.metrics = metrics
